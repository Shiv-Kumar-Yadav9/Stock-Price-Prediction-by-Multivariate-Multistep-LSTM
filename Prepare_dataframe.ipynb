# %%
import pandas as pd

# %%
Shares=['ASIANPAINT','BHARTIARTL','CIPLA','HCLTECH','HDFCBANK','HINDUNILVR','ICICIBANK','INDUSINDBK','INFY','ITC','KOTAKBANK','LT','M&M','MARUTI','NTPC','ONGC','POWERGRID','RELIANCE','SBIN','SUNPHARMA','TATAMOTORS','TCS','TECHM','VEDL']
for t in Shares:
    print(t)
    gail=pd.read_csv("./DATASET/"+t+"/01-01-2010-TO-31-12-2010"+t+"EQN.csv",index_col="Date",parse_dates=True)#,date_parser=["Date"])
    df2=pd.read_csv("./DATASET/"+t+"/01-01-2011-TO-31-12-2011"+t+"EQN.csv",index_col="Date",parse_dates=True)
    df3=pd.read_csv("./DATASET/"+t+"/01-01-2012-TO-31-12-2012"+t+"EQN.csv",index_col="Date",parse_dates=True)
    df4=pd.read_csv("./DATASET/"+t+"/01-01-2013-TO-31-12-2013"+t+"EQN.csv",index_col="Date",parse_dates=True)
    df5=pd.read_csv("./DATASET/"+t+"/01-01-2014-TO-31-12-2014"+t+"EQN.csv",index_col="Date",parse_dates=True)
    df6=pd.read_csv("./DATASET/"+t+"/01-01-2015-TO-31-12-2015"+t+"EQN.csv",index_col="Date",parse_dates=True)
    df7=pd.read_csv("./DATASET/"+t+"/01-01-2016-TO-31-12-2016"+t+"EQN.csv",index_col="Date",parse_dates=True)
    df8=pd.read_csv("./DATASET/"+t+"/01-01-2017-TO-31-12-2017"+t+"EQN.csv",index_col="Date",parse_dates=True)
    df9=pd.read_csv("./DATASET/"+t+"/01-01-2018-TO-31-12-2018"+t+"EQN.csv",index_col="Date",parse_dates=True)
    df10=pd.read_csv("./DATASET/02-06-2018-TO-01-02-2019"+t+"EQN.csv",index_col="Date",parse_dates=True)
    gail_all = gail.append([df2,df3,df4,df5,df6,df7,df8,df9,df10])
    gail_all.head(10)
    
    #to save the file
    f=open(t+'_all.csv', 'w')
    #f.write("Date,Close\n")
    for i in range(gail_all.shape[0]):
        if i !=0:
            s="\n"
        else:
            s=''
        item=s+str(gail_all.index[i])+","+str(gail_all["Close Price"][i])
        f.write(item)
    f.close()
# Out:
# ASIANPAINT
# C:\Users\Logic\Anacondat3\Lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# BHARTIARTL
# CIPLA
# HCLTECH
# HDFCBANK
# HINDUNILVR
# ICICIBANK
# INDUSINDBK
# INFY
# ITC
# KOTAKBANK
# LT
# M&M
# MARUTI
# NTPC
# ONGC
# POWERGRID
# RELIANCE
# SBIN
# SUNPHARMA
# TATAMOTORS
# TCS
# TECHM
# VEDL
